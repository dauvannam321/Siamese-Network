# %% [markdown]
# <a href="https://colab.research.google.com/github/dauvannam321/Siamese-Network/blob/main/Train_Siamese_network_ReID_Dataset_Oxford_Building_(5K).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Dataset Oxford Building (5K)**
# More information: <br>
# https://www.robots.ox.ac.uk/~vgg/data/oxbuildings/ <br>
# https://www.kaggle.com/datasets/skylord/oxbuildings?select=oxbuild_images.tgz

# %%
import os

# %%
from google.colab import files
files=files.upload()
# Out:
#      <input type="file" id="files-d0665542-a567-4bf3-b533-fe2cdb002de5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d0665542-a567-4bf3-b533-fe2cdb002de5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets download -d 'skylord/oxbuildings'
# Out:
# ...
# 100% 4.26G/4.28G [00:28<00:00, 214MB/s]
# 100% 4.28G/4.28G [00:29<00:00, 158MB/s]

# %%
# !unzip 'oxbuildings.zip'
# Out:
# Archive:  oxbuildings.zip
#   inflating: oxbuild_images.tgz
#   inflating: paris_1.tgz
#   inflating: paris_2.tgz

# %%
if not os.path.exists('/content/images'):
  os.mkdir('/content/images')

# %%
# !tar -xvf/content/oxbuild_images.tgz -C /content/images
# Out:
# Streaming output truncated to the last 5000 lines.
# all_souls_000093.jpg
# all_souls_000095.jpg
# all_souls_000097.jpg
# all_souls_000099.jpg
# all_souls_000100.jpg
# all_souls_000101.jpg
# all_souls_000102.jpg
# all_souls_000103.jpg
# all_souls_000105.jpg
# all_souls_000106.jpg
# all_souls_000107.jpg
# all_souls_000110.jpg
# all_souls_000114.jpg
# all_souls_000117.jpg
# all_souls_000119.jpg
# all_souls_000120.jpg
# all_souls_000126.jpg
# all_souls_000130.jpg
# all_souls_000131.jpg
# all_souls_000132.jpg
# all_souls_000133.jpg
# all_souls_000134.jpg
# all_souls_000136.jpg
# all_souls_000140.jpg
# all_souls_000142.jpg
# all_souls_000143.jpg
# all_souls_000144.jpg
# all_souls_000145.jpg
# all_souls_000146.jpg
# all_souls_000148.jpg
# all_souls_000149.jpg
# all_souls_000150.jpg
# all_souls_000151.jpg
# all_souls_000152.jpg
# all_souls_000153.jpg
# all_souls_000157.jpg
# all_souls_000159.jpg
# all_souls_000160.jpg
# all_souls_000161.jpg
# all_souls_000162.jpg
# all_souls_000167.jpg
# ...

# %%
# !wget https://www.robots.ox.ac.uk/~vgg/data/oxbuildings/gt_files_170407.tgz
# Out:
# --2023-03-18 08:02:55--  https://www.robots.ox.ac.uk/~vgg/data/oxbuildings/gt_files_170407.tgz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/datasets/oxford-buildings/gt_files_170407.tgz [following]
# --2023-03-18 08:02:56--  https://thor.robots.ox.ac.uk/datasets/oxford-buildings/gt_files_170407.tgz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8174 (8.0K) [application/octet-stream]
# Saving to: ‘gt_files_170407.tgz’
#
# gt_files_170407.tgz 100%[===================>]   7.98K  --.-KB/s    in 0s
#
# 2023-03-18 08:02:56 (1.18 GB/s) - ‘gt_files_170407.tgz’ saved [8174/8174]

# %%
if not os.path.exists('/content/gt'):
  os.mkdir('/content/gt')

# %%
# !tar -xvf /content/gt_files_170407.tgz -C /content/gt
# Out:
# all_souls_1_good.txt
# all_souls_1_junk.txt
# all_souls_1_ok.txt
# all_souls_1_query.txt
# all_souls_2_good.txt
# all_souls_2_junk.txt
# all_souls_2_ok.txt
# all_souls_2_query.txt
# all_souls_3_good.txt
# all_souls_3_junk.txt
# all_souls_3_ok.txt
# all_souls_3_query.txt
# all_souls_4_good.txt
# all_souls_4_junk.txt
# all_souls_4_ok.txt
# all_souls_4_query.txt
# all_souls_5_good.txt
# all_souls_5_junk.txt
# all_souls_5_ok.txt
# all_souls_5_query.txt
# ashmolean_1_good.txt
# ashmolean_1_junk.txt
# ashmolean_1_ok.txt
# ashmolean_1_query.txt
# ashmolean_2_good.txt
# ashmolean_2_junk.txt
# ashmolean_2_ok.txt
# ashmolean_2_query.txt
# ashmolean_3_good.txt
# ashmolean_3_junk.txt
# ashmolean_3_ok.txt
# ashmolean_3_query.txt
# ashmolean_4_good.txt
# ashmolean_4_junk.txt
# ashmolean_4_ok.txt
# ashmolean_4_query.txt
# ashmolean_5_good.txt
# ashmolean_5_junk.txt
# ashmolean_5_ok.txt
# ashmolean_5_query.txt
# balliol_1_good.txt
# balliol_1_junk.txt
# balliol_1_ok.txt
# balliol_1_query.txt
# ...

# %% [markdown]
# #**Install envi + import lib**

# %%
### Install Environment
# !pip install timm
# !pip install faiss-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 KB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 22.4 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 11.8 MB/s eta 0:00:00
# ...

# %%
# Importing all the necessary libraries for the code to run.
import timm
import sys
import torch
from torch.optim import lr_scheduler
import torch.optim as optim
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split
import cv2
import numpy as np
import copy
import random
from PIL import Image
import faiss
from tqdm import tqdm, tqdm_notebook
import os
import shutil
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import json

# %%
cuda = torch.cuda.is_available()

# %% [markdown]
# #**Prepare data**

# %%
# Creating a dictionary of image file paths.
query_categories = ['all_souls', 'ashmolean', 'balliol', 'bodleian', 'christ_church',
                  'cornmarket', 'hertford', 'keble', 'magdalen', 'pitt_rivers', 'radcliffe_camera'] 

data_categories = ['trinity', 'bodleian', 'oxford', 'magdalen', 'balliol', 
                  'christ_church', 'oriel', 'all_souls', 'pitt_rivers', 'ashmolean', 
                  'new', 'radcliffe_camera', 'jesus', 'keble', 'worcester', 'hertford', 'cornmarket']
# {'trinity': 217, 'bodleian': 214, 'oxford': 1502, 
# 'magdalen': 685, 'balliol': 154, 'christ_church': 543,
#  'oriel': 95, 'all_souls': 132, 'pitt_rivers': 108,
#   'ashmolean': 195, 'new': 458, 'radcliffe_camera': 282,
#    'jesus': 161, 'keble': 121, 'worcester': 70, 'hertford': 67, 'cornmarket': 59} 

root_img_path = '/content/images'
new_img_path = '/content/data'
if not os.path.exists(new_img_path):
  os.mkdir(new_img_path)
files = []

for folder in os.listdir(root_img_path):
  file_name = ''
  if folder.count('_') == 2:
    file_name = folder.split('_')[0] + '_' + folder.split('_')[1]
  else:
    file_name = folder.split('_')[0]
  if file_name in data_categories:
    img_path = os.path.join(root_img_path, folder)
    new_path = os.path.join(new_img_path, file_name)
    if not os.path.exists(new_path):
      os.mkdir(new_path)
    shutil.copy(img_path, new_path)

# %%
# Create pairs of images path and their label (positive and negative)
root_data_path = '/content/data'
count = 0
pairs_of_imgs = []

for sub_folder in os.listdir(root_data_path):
  print(sub_folder)
  subdir_path = os.path.join(root_data_path, sub_folder)

  for img_file in os.listdir(subdir_path):
    img1_path = os.path.join(subdir_path, img_file)
    target = np.random.randint(0, 2)
    
    if target == 1:
      #select random image in the same folder
      random_img_name = random.choice(os.listdir(subdir_path))
      img2_path = os.path.join(subdir_path, random_img_name)
      count += 1

    else:
      random_orther_folder = random.choice([x for x in os.listdir(root_data_path) if x not in [sub_folder] ])
      random_orther_folder_path = os.path.join(root_data_path, random_orther_folder)

      random_img_name = random.choice(os.listdir(random_orther_folder_path))
      img2_path = os.path.join(random_orther_folder_path, random_img_name)
      count +=1
    
    pairs_of_imgs.append([img1_path, img2_path, target])
    # print(img1_path)
    # print(img2_path)
    # print(target)
    # print('*' * 20)

      
print(count)
# Out:
# hertford
# oriel
# radcliffe_camera
# worcester
# ashmolean
# new
# keble
# bodleian
# pitt_rivers
# balliol
# magdalen
# cornmarket
# all_souls
# christ_church
# trinity
# jesus
# oxford
# 5063

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Chỉnh kích thước ảnh
    transforms.ToTensor()          # Chuyển đổi sang tensor
])

# %%
# create [((img1,img2),label), ((img1,img2),label), ...]
data = []
for i in range(len(pairs_of_imgs)):
  # print(pairs_of_imgs[i]) ['/content/data/oxford/oxford_000460.jpg', '/content/data/hertford/hertford_000060.jpg', 0]
  img1 = transform(Image.open(pairs_of_imgs[i][0]))
  img2 = transform(Image.open(pairs_of_imgs[i][1]))
  label = pairs_of_imgs[i][2]
  data.append(((img1,img2),label))

# %%
train_data, remain_data = train_test_split(data, test_size=0.3)
valid_data, test_data = train_test_split(remain_data, test_size=0.3)

# %%
# train_data[0][0][0].shape #torch.Size([3, 224, 224])

# %%
# print(len(train_data)) # 3544
# print(len(valid_data)) # 1063
# print(len(test_data)) # 456

# %% [markdown]
# #**Data loader**

# %%
batch_size = 32
kwargs = {'num_workers': 1, 'pin_memory': True} if cuda else {}
siamese_train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, **kwargs)
siamese_valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size, shuffle=False, **kwargs)
siamese_test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False, **kwargs)

# %% [markdown]
# #**Embedding + SiameseNet**

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class EmbeddingNet(nn.Module):
  def __init__(self):
    super(EmbeddingNet, self).__init__()
    self.convnet = nn.Sequential(nn.Conv2d(3, 32, 5), nn.PReLU(),
                                  nn.MaxPool2d(2, stride=2),
                                  nn.Conv2d(32, 64, 5), nn.PReLU(),
                                  nn.MaxPool2d(2, stride=2))

    self.fc = nn.Sequential(nn.Linear(179776, 64),
                            nn.PReLU(),
                            nn.Linear(64, 64),
                            nn.PReLU(),
                            nn.Linear(64, 3)
                            )

  def forward(self, x):
    output = self.convnet(x)
    output = output.view(output.size()[0], -1)
    output = self.fc(output)
    return output

  def get_embedding(self, x):
    return self.forward(x)

# %%
class SiameseNet(nn.Module):
  def __init__(self, embedding_net):
    super(SiameseNet, self).__init__()
    self.embedding_net = embedding_net

  def forward(self, x1, x2):
    output1 = self.embedding_net(x1)
    output2 = self.embedding_net(x2)
    return output1, output2

  def get_embedding(self, x):
    return self.embedding_net(x)

# %%
# print(test_data[0][0][0].shape) # torch.Size([3, 224, 224])

# %%
# print(test_data[0][0][1].shape) # torch.Size([3, 224, 224])

# %%
# print(test_data[0][1]) # 1

# %%
# import matplotlib.pyplot as plt

# # Convert PyTorch tensor to a numpy array
# image1 = test_data[0][0][0].permute(1, 2, 0).numpy()
# image2 = test_data[0][0][1].permute(1, 2, 0).numpy()

# fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# # Plot the first image in the left column
# axs[0].imshow(image1)
# axs[0].set_title('Image 1')

# # Plot the second image in the right column
# axs[1].imshow(image2)
# axs[1].set_title('Image 2')
# plt.show()

# %%
embedding_net = EmbeddingNet()
print(embedding_net)
# Out:
# EmbeddingNet(
#   (convnet): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): PReLU(num_parameters=1)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): PReLU(num_parameters=1)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=179776, out_features=64, bias=True)
#     (1): PReLU(num_parameters=1)
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): PReLU(num_parameters=1)
#     (4): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %%
# print(test_data[0][0][0].unsqueeze(0).shape) # torch.Size([1, 3, 224, 224])

# %%
# out1 = embedding_net.get_embedding(test_data[0][0][0].unsqueeze(0))
# out2 = embedding_net.get_embedding(test_data[0][0][1].unsqueeze(0))

# %%
# print(type(out1)) # <class 'torch.Tensor'>

# %%
# print(out1) # tensor([[-0.0003, -0.0062, -0.0828]], grad_fn=<AddmmBackward0>)

# %%
# # Calculate the cosine similarity
# cosine_sim = torch.nn.functional.cosine_similarity(out1, out2)

# # Print the result
# print(cosine_sim)
# # tensor([0.9970], grad_fn=<SumBackward1>)

# %% [markdown]
# #**Contrastive Loss**

# %%
class ContrastiveLoss(nn.Module):
    """
    Contrastive loss
    Takes embeddings of two samples and a target label == 1 if samples are from the same class and label == 0 otherwise
    """

    def __init__(self, margin):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin
        self.eps = 1e-9

    def forward(self, output1, output2, target, size_average=True):
        distances = (output2 - output1).pow(2).sum(1)  # squared distances
        losses = 0.5 * (target.float() * distances +
                        (1 + -1 * target).float() * F.relu(self.margin - (distances + self.eps).sqrt()).pow(2))
        return losses.mean() if size_average else losses.sum()

# %% [markdown]
# #**Trainer**

# %%
import torch
import numpy as np


def fit(train_loader, val_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, log_interval, metrics=[],
        start_epoch=0):
    """
    Loaders, model, loss function and metrics should work together for a given task,
    i.e. The model should be able to process data output of loaders,
    loss function should process target output of loaders and outputs from the model
    Examples: Classification: batch loader, classification model, NLL loss, accuracy metric
    Siamese network: Siamese loader, siamese model, contrastive loss
    Online triplet learning: batch loader, embedding model, online triplet loss
    """
    train_losses = []
    val_losses = []
    for epoch in range(0, start_epoch):
        scheduler.step()

    for epoch in range(start_epoch, n_epochs):
        scheduler.step()

        # Train stage
        train_loss, metrics = train_epoch(train_loader, model, loss_fn, optimizer, cuda, log_interval, metrics)

        message = 'Epoch: {}/{}. Train set: Average loss: {:.4f}'.format(epoch + 1, n_epochs, train_loss)
        for metric in metrics:
            message += '\t{}: {}'.format(metric.name(), metric.value())

        val_loss, metrics = test_epoch(val_loader, model, loss_fn, cuda, metrics)
        val_loss /= len(val_loader)

        message += '\nEpoch: {}/{}. Validation set: Average loss: {:.4f}'.format(epoch + 1, n_epochs,
                                                                                 val_loss)
        for metric in metrics:
            message += '\t{}: {}'.format(metric.name(), metric.value())

        print(message)
        train_losses.append(train_loss)
        val_losses.append(val_loss)
    
    return train_losses, val_losses


def train_epoch(train_loader, model, loss_fn, optimizer, cuda, log_interval, metrics):
    for metric in metrics:
        metric.reset()

    model.train()
    losses = []
    total_loss = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        target = target if len(target) > 0 else None
        if not type(data) in (tuple, list):
            data = (data,)
        if cuda:
            data = tuple(d.cuda() for d in data)
            if target is not None:
                target = target.cuda()


        optimizer.zero_grad()
        outputs = model(*data)

        if type(outputs) not in (tuple, list):
            outputs = (outputs,)

        loss_inputs = outputs
        if target is not None:
            target = (target,)
            loss_inputs += target

        loss_outputs = loss_fn(*loss_inputs)
        loss = loss_outputs[0] if type(loss_outputs) in (tuple, list) else loss_outputs
        losses.append(loss.item())
        total_loss += loss.item()
        loss.backward()
        optimizer.step()

        for metric in metrics:
            metric(outputs, target, loss_outputs)

        if batch_idx % log_interval == 0:
            message = 'Train: [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                batch_idx * len(data[0]), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), np.mean(losses))
            for metric in metrics:
                message += '\t{}: {}'.format(metric.name(), metric.value())

            print(message)
            losses = []

    total_loss /= (batch_idx + 1)
    return total_loss, metrics


def test_epoch(val_loader, model, loss_fn, cuda, metrics):
    with torch.no_grad():
        for metric in metrics:
            metric.reset()
        model.eval()
        val_loss = 0
        for batch_idx, (data, target) in enumerate(val_loader):
            target = target if len(target) > 0 else None
            if not type(data) in (tuple, list):
                data = (data,)
            if cuda:
                data = tuple(d.cuda() for d in data)
                if target is not None:
                    target = target.cuda()

            outputs = model(*data)

            if type(outputs) not in (tuple, list):
                outputs = (outputs,)
            loss_inputs = outputs
            if target is not None:
                target = (target,)
                loss_inputs += target

            loss_outputs = loss_fn(*loss_inputs)
            loss = loss_outputs[0] if type(loss_outputs) in (tuple, list) else loss_outputs
            val_loss += loss.item()

            for metric in metrics:
                metric(outputs, target, loss_outputs)

    return val_loss, metrics

# %% [markdown]
# #**Train model**

# %%
model = SiameseNet(embedding_net)
cuda = torch.cuda.is_available()
model.cuda()
# Out:
# SiameseNet(
#   (embedding_net): EmbeddingNet(
#     (convnet): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#       (1): PReLU(num_parameters=1)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#       (4): PReLU(num_parameters=1)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (fc): Sequential(
#       (0): Linear(in_features=179776, out_features=64, bias=True)
#       (1): PReLU(num_parameters=1)
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): PReLU(num_parameters=1)
#       (4): Linear(in_features=64, out_features=3, bias=True)
#     )
#   )
# )

# %%
loss_fn = ContrastiveLoss(1)

# %%
lr = 1e-3
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 50
log_interval = 100

# %%
history = fit(siamese_train_loader, siamese_test_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, log_interval)
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/optim/lr_scheduler.py:138: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Train: [0/3544 (0%)]	Loss: 0.291217
# Train: [3200/3544 (90%)]	Loss: 0.173979
# Epoch: 1/50. Train set: Average loss: 0.1734
# Epoch: 1/50. Validation set: Average loss: 0.1441
# Train: [0/3544 (0%)]	Loss: 0.174877
# Train: [3200/3544 (90%)]	Loss: 0.144016
# Epoch: 2/50. Train set: Average loss: 0.1446
# Epoch: 2/50. Validation set: Average loss: 0.1393
# Train: [0/3544 (0%)]	Loss: 0.142889
# Train: [3200/3544 (90%)]	Loss: 0.132041
# ...

# %%
# Save the weights of the model to a file
# torch.save(model.state_dict(), 'SiamemeNet_weights.pth')

# %%
# Vẽ biểu đồ cho hai đường cong loss
plt.plot(history[0], label='train loss')
plt.plot(history[1], label='valid loss')

# Đặt tiêu đề cho biểu đồ và trục
plt.title('Loss over time')
plt.xlabel('Epoch')
plt.ylabel('Loss')

# Đặt chú thích cho biểu đồ
plt.legend()

# Hiển thị biểu đồ
plt.show()
